# %%
print('hello')
# Out:
# hello

# %%
from inspect_ai import Task, task
from inspect_ai.dataset import Sample
from inspect_ai.scorer import exact
from inspect_ai.solver import generate

@task
def hello_world():
    return Task(
        dataset=[
            Sample(
                input="Just reply with Hello World",
                target="Hello World",
            )
        ],
        solver=[generate()],
        scorer=exact(),
    )

# %%
from inspect_ai import Task, task
from inspect_ai.dataset import example_dataset
from inspect_ai.scorer import model_graded_fact
from inspect_ai.solver import generate, system_message

SYSTEM_MESSAGE = """
You are a computer security expert and you are tasked with
providing concise response to the following questions.
Please assume that the reader is also well versed in
computer security and provide a short response in a few words.
"""

@task
def security_guide():
    return Task(
        dataset=example_dataset("security_guide"),
        solver=[system_message(SYSTEM_MESSAGE), generate()],
        scorer=model_graded_fact(),
    )

# %%
from inspect_ai import eval

results = eval(hello_world())  # where hello_world is your @task function
# Out:
# Output()
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/run.py:886 in task_run_sample                                                                       │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/anyio/_back │
# │ ends/_asyncio.py:783 in __aexit__                                                                              │
# │                                                                                                                │
# │    780 │   │   │   │   │   # added to self._exceptions so it's ok to break exception                           │
# │    781 │   │   │   │   │   # chaining and avoid adding a "During handling of above..."                         │
# │    782 │   │   │   │   │   # for each nesting level.                                                           │
# │ >  783 │   │   │   │   │   raise BaseExceptionGroup(                                                           │
# │    784 │   │   │   │   │   │   "unhandled errors in a TaskGroup", self._exceptions                             │
# │    785 │   │   │   │   │   ) from None                                                                         │
# │    786 │   │   │   │   elif exc_val:                                                                           │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#
# ┌─────────────────────────────────────────────── Sub-exception #1 ───────────────────────────────────────────────┐
# │ ┌──────────────────────────────────── Traceback (most recent call last) ─────────────────────────────────────┐ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect │ │
# │ │ _ai/_eval/task/run.py:889 in task_run_sample                                                               │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/asyncio/ta │ │
# │ │ sks.py:304 in __step_run_and_handle_result                                                                 │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect │ │
# │ │ _ai/_eval/task/run.py:808 in run                                                                           │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect │ │
# │ │ _ai/solver/_plan.py:105 in __call__                                                                        │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect │ │
# │ │ _ai/solver/_solver.py:291 in solve                                                                         │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect │ │
# │ │ _ai/_eval/task/run.py:314 in generate                                                                      │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect │ │
# │ │ _ai/_eval/task/generate.py:28 in task_generate                                                             │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect │ │
# │ │ _ai/model/_model.py:555 in generate                                                                        │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect │ │
# │ │ _ai/model/_model.py:923 in _generate                                                                       │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacit │ │
# │ │ y/asyncio/__init__.py:189 in async_wrapped                                                                 │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacit │ │
# │ │ y/asyncio/__init__.py:111 in __call__                                                                      │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacit │ │
# │ │ y/asyncio/__init__.py:153 in iter                                                                          │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacit │ │
# │ │ y/_utils.py:99 in inner                                                                                    │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacit │ │
# │ │ y/__init__.py:400 in <lambda>                                                                              │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/concurrent │ │
# │ │ /futures/_base.py:449 in result                                                                            │ │
# │ │                                                                                                            │ │
# │ │   446 │   │   │   │   if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:                               │ │
# │ │   447 │   │   │   │   │   raise CancelledError()                                                           │ │
# │ │   448 │   │   │   │   elif self._state == FINISHED:                                                        │ │
# │ │ > 449 │   │   │   │   │   return self.__get_result()                                                       │ │
# │ │   450 │   │   │   │                                                                                        │ │
# │ │   451 │   │   │   │   self._condition.wait(timeout)                                                        │ │
# │ │   452                                                                                                      │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/concurrent │ │
# │ │ /futures/_base.py:401 in __get_result                                                                      │ │
# │ │                                                                                                            │ │
# │ │   398 │   def __get_result(self):                                                                          │ │
# │ │   399 │   │   if self._exception is not None:                                                              │ │
# │ │   400 │   │   │   try:                                                                                     │ │
# │ │ > 401 │   │   │   │   raise self._exception                                                                │ │
# │ │   402 │   │   │   finally:                                                                                 │ │
# │ │   403 │   │   │   │   # Break a reference cycle with the exception in self._exception                      │ │
# │ │   404 │   │   │   │   self = None                                                                          │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacit │ │
# │ │ y/asyncio/__init__.py:114 in __call__                                                                      │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect │ │
# │ │ _ai/model/_model.py:854 in generate                                                                        │ │
# │ │                                                                                                            │ │
# │ │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect │ │
# │ │ _ai/model/_providers/none.py:29 in generate                                                                │ │
# │ └────────────────────────────────────────────────────────────────────────────────────────────────────────────┘ │
# │ PrerequisiteError: No model specified (and no model environment varible defined)                               │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# During handling of the above exception, another exception occurred:
#
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/run.py:889 in task_run_sample                                                                       │
# │                                                                                                                │
# │ /Users/traviswhitfield/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/asyncio/tasks. │
# │ py:304 in __step_run_and_handle_result                                                                         │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/run.py:808 in run                                                                                   │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ solver/_plan.py:105 in __call__                                                                                │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ solver/_solver.py:291 in solve                                                                                 │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/run.py:314 in generate                                                                              │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/generate.py:28 in task_generate                                                                     │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ model/_model.py:555 in generate                                                                                │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ model/_model.py:923 in _generate                                                                               │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/as │
# │ yncio/__init__.py:189 in async_wrapped                                                                         │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/as │
# │ yncio/__init__.py:111 in __call__                                                                              │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/as │
# │ yncio/__init__.py:153 in iter                                                                                  │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/_u │
# │ tils.py:99 in inner                                                                                            │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/__ │
# │ init__.py:400 in <lambda>                                                                                      │
# │                                                                                                                │
# │ /Users/traviswhitfield/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/concurrent/fut │
# │ ures/_base.py:449 in result                                                                                    │
# │                                                                                                                │
# │   446 │   │   │   │   if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:                                   │
# │   447 │   │   │   │   │   raise CancelledError()                                                               │
# │   448 │   │   │   │   elif self._state == FINISHED:                                                            │
# │ > 449 │   │   │   │   │   return self.__get_result()                                                           │
# │   450 │   │   │   │                                                                                            │
# │   451 │   │   │   │   self._condition.wait(timeout)                                                            │
# │   452                                                                                                          │
# │                                                                                                                │
# │ /Users/traviswhitfield/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/concurrent/fut │
# │ ures/_base.py:401 in __get_result                                                                              │
# │                                                                                                                │
# │   398 │   def __get_result(self):                                                                              │
# │   399 │   │   if self._exception is not None:                                                                  │
# │   400 │   │   │   try:                                                                                         │
# │ > 401 │   │   │   │   raise self._exception                                                                    │
# │   402 │   │   │   finally:                                                                                     │
# │   403 │   │   │   │   # Break a reference cycle with the exception in self._exception                          │
# │   404 │   │   │   │   self = None                                                                              │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/as │
# │ yncio/__init__.py:114 in __call__                                                                              │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ model/_model.py:854 in generate                                                                                │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ model/_providers/none.py:29 in generate                                                                        │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# PrerequisiteError: No model specified (and no model environment varible defined)
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/run.py:418 in task_run                                                                              │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _util/_async.py:76 in tg_collect                                                                               │
# │                                                                                                                │
# │ /Users/traviswhitfield/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/asyncio/tasks. │
# │ py:304 in __step_run_and_handle_result                                                                         │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _util/_async.py:64 in run_task                                                                                 │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/run.py:385 in run_sample                                                                            │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/run.py:1112 in task_run_sample                                                                      │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/run.py:889 in task_run_sample                                                                       │
# │                                                                                                                │
# │ /Users/traviswhitfield/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/asyncio/tasks. │
# │ py:304 in __step_run_and_handle_result                                                                         │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/run.py:808 in run                                                                                   │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ solver/_plan.py:105 in __call__                                                                                │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ solver/_solver.py:291 in solve                                                                                 │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/run.py:314 in generate                                                                              │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ _eval/task/generate.py:28 in task_generate                                                                     │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ model/_model.py:555 in generate                                                                                │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ model/_model.py:923 in _generate                                                                               │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/as │
# │ yncio/__init__.py:189 in async_wrapped                                                                         │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/as │
# │ yncio/__init__.py:111 in __call__                                                                              │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/as │
# │ yncio/__init__.py:153 in iter                                                                                  │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/_u │
# │ tils.py:99 in inner                                                                                            │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/__ │
# │ init__.py:400 in <lambda>                                                                                      │
# │                                                                                                                │
# │ /Users/traviswhitfield/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/concurrent/fut │
# │ ures/_base.py:449 in result                                                                                    │
# │                                                                                                                │
# │   446 │   │   │   │   if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:                                   │
# │   447 │   │   │   │   │   raise CancelledError()                                                               │
# │   448 │   │   │   │   elif self._state == FINISHED:                                                            │
# │ > 449 │   │   │   │   │   return self.__get_result()                                                           │
# │   450 │   │   │   │                                                                                            │
# │   451 │   │   │   │   self._condition.wait(timeout)                                                            │
# │   452                                                                                                          │
# │                                                                                                                │
# │ /Users/traviswhitfield/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/concurrent/fut │
# │ ures/_base.py:401 in __get_result                                                                              │
# │                                                                                                                │
# │   398 │   def __get_result(self):                                                                              │
# │   399 │   │   if self._exception is not None:                                                                  │
# │   400 │   │   │   try:                                                                                         │
# │ > 401 │   │   │   │   raise self._exception                                                                    │
# │   402 │   │   │   finally:                                                                                     │
# │   403 │   │   │   │   # Break a reference cycle with the exception in self._exception                          │
# │   404 │   │   │   │   self = None                                                                              │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/tenacity/as │
# │ yncio/__init__.py:114 in __call__                                                                              │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ model/_model.py:854 in generate                                                                                │
# │                                                                                                                │
# │ /Users/traviswhitfield/Documents/github/trav_ai_control_sandbox/.venv/lib/python3.13/site-packages/inspect_ai/ │
# │ model/_providers/none.py:29 in generate                                                                        │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# PrerequisiteError: No model specified (and no model environment varible defined)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
import anthropic

# %%
import os

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
client = anthropic.Anthropic(
    api_key=os.environ['ANTHROPIC_API_KEY']
)

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# claude-opus-4-5-20251101
# claude-haiku-4-5-20251001
# claude-sonnet-4-5-20250929
# claude-opus-4-1-20250805
# claude-opus-4-20250514
# claude-sonnet-4-20250514
# claude-3-5-haiku-20241022
# claude-3-haiku-20240307
